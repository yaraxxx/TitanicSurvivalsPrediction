# %% [markdown]
# # Tuning Voting Models with Hyper-Parameters
# - [very useful link that explains tuning the hyper-parameters](https://scikit-learn.org/stable/modules/grid_search.html#grid-search)
# - [Parameter estimation using grid search with cross-validation](https://scikit-learn.org/stable/auto_examples/model_selection/plot_grid_search_digits.html)
#
# Since Tuning hyper-parameters is time expensive this notebokk is for testing each model to find the best parameters for each model used in voting classifier , so that I use the parameters without testing all models for all possible parameters that might improve the testing score.

# %%
import pandas as pd
import numpy as np
import pickle
import time
import json

# models 
from sklearn import ensemble
from sklearn import gaussian_process
from sklearn import linear_model 
from sklearn import naive_bayes
from sklearn import neighbors
from sklearn import svm
from sklearn import tree
from sklearn import discriminant_analysis
from sklearn import model_selection

# %%
# loading variables from the other Notebook
# https://ipython.org/ipython-doc/rel-0.12/config/extensions/storemagic.html
# %store -r train_set_cpy
# %store -r Target
# %store -r train_x_bins
# %store -r cross_validator_split

# %%
grid_n_estimator = [10, 50, 100, 300]
grid_ratio = [.1, .25, .5, .75, 1.0]
grid_learn = [.03, .05, .1, .25]
grid_max_depth = [2, 3 , 4, 6, 8, None]
grid_min_samples = [5, 10, .03, .05, .10]
grid_criterion = ['gini', 'entropy']
grid_bool = [True, False]
min_samples_leaf = [1,5,10,.03,.05]
max_features = [None, 'auto','log2','sqrt']
grid_seed = [0]

# %% [markdown]
# # 1 |  Ensemble Methods

# %%
#http://scikit-learn.org/stable/modules/ensemble.html
est_1 = [
    ('abc',ensemble.AdaBoostClassifier()),
    ('bc', ensemble.BaggingClassifier()),
    ('etc', ensemble.ExtraTreesClassifier()),
    ('gbc', ensemble.GradientBoostingClassifier()),
    ('rfc', ensemble.RandomForestClassifier())
]

# %%
param_grid_1 = [
            # AdaBoostClassifier 
            # https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html?highlight=adaboostclassifier#sklearn.ensemble.AdaBoostClassifier
            {
            'n_estimators': grid_n_estimator, #default=50
            'learning_rate': grid_learn, #default=1
            'algorithm': ['SAMME.R'], #default=’SAMME.R
            'random_state': grid_seed
            },
            #BaggingClassifier 
            # http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.BaggingClassifier.html#sklearn.ensemble.BaggingClassifier
            {
            'n_estimators' : grid_n_estimator, #default=10
            'max_features' : grid_ratio,
            'random_state' : grid_seed
            },
            {
             # ExtraTreesClassifier
            # http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.ExtraTreesClassifier.html#sklearn.ensemble.ExtraTreesClassifier
            'n_estimators' : [100, 300 , 500], #defualt = 100
            'criterion' : grid_criterion,
            'max_depth' : grid_max_depth, #defualt = None
            'min_samples_leaf' : min_samples_leaf,
            'max_features' : max_features,
            'random_state' : grid_seed
            },
            {
            # GradientBoostingClassifier
            # http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html#sklearn.ensemble.GradientBoostingClassifier
            'learning_rate' :grid_learn,
            'n_estimators' : [100, 300 , 500], #defualt = 100
            'min_samples_leaf' : min_samples_leaf,
            'max_depth' : grid_max_depth,
            'max_features' : max_features,
            'random_state' : grid_seed
            },
            {
            # RandomForestClassifier
            # http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn.ensemble.RandomForestClassifier
            'n_estimators' : [100, 300 , 500], #defualt = 100
            'criterion' : grid_criterion,
            'max_depth' : grid_max_depth,
            'oob_score' : [True],
            'random_state' : grid_seed
            }
            ]

# %%
# To test and see how zip will work 
for clf,param in zip(est_1,param_grid_1):
    print("Name : {}\nAlgorithm: {}".format(clf[0],clf[1]))
    print("Parameters grid : {}".format(param))
    print('-'*30)
# Out:
# Name : abc
# Algorithm: AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=None)
# Parameters grid : {'n_estimators': [10, 50, 100, 300], 'learning_rate': [0.03, 0.05, 0.1, 0.25], 'algorithm': ['SAMME.R'], 'random_state': [0]}
# ------------------------------
# Name : bc
# Algorithm: BaggingClassifier(base_estimator=None, bootstrap=True, bootstrap_features=False,
#                   max_features=1.0, max_samples=1.0, n_estimators=10,
#                   n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                   warm_start=False)
# Parameters grid : {'n_estimators': [10, 50, 100, 300], 'max_features': [0.1, 0.25, 0.5, 0.75, 1.0], 'random_state': [0]}
# ------------------------------
# Name : etc
# Algorithm: ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)
# Parameters grid : {'n_estimators': [100, 300, 500], 'criterion': ['gini', 'entropy'], 'max_depth': [2, 3, 4, 6, 8, None], 'min_samples_leaf': [1, 5, 10, 0.03, 0.05], 'max_features': [None, 'auto', 'log2', 'sqrt'], 'random_state': [0]}
# ------------------------------
# Name : gbc
# Algorithm: GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
# Parameters grid : {'learning_rate': [0.03, 0.05, 0.1, 0.25], 'n_estimators': [100, 300, 500], 'min_samples_leaf': [1, 5, 10, 0.03, 0.05], 'max_depth': [2, 3, 4, 6, 8, None], 'max_features': [None, 'auto', 'log2', 'sqrt'], 'random_state': [0]}
# ------------------------------
# Name : rfc
# Algorithm: RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# Parameters grid : {'n_estimators': [100, 300, 500], 'criterion': ['gini', 'entropy'], 'max_depth': [2, 3, 4, 6, 8, None], 'oob_score': [True], 'random_state': [0]}
# ------------------------------

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html#sklearn.model_selection.GridSearchCV
save_best_params = {}
def findBestParam(est , param_grid):
    start_total = time.perf_counter()
    for clf,param in zip(est,param_grid):
        start = time.perf_counter()
        tune_model = model_selection.GridSearchCV(clf[1],
                                                 param_grid = param,
                                                 scoring = 'roc_auc',
                                                 cv = cross_validator_split,
                                                 return_train_score = True)
    
        tune_model.fit(train_set_cpy[train_x_bins],train_set_cpy[Target].values.ravel())
    
        run = time.perf_counter() - start
    
        alg_name = clf[1].__class__.__name__ 
        params = tune_model.best_params_
        
        print("The best parameters for {} are {} with runtime of {:.2f} seconds".format(
        alg_name, params , run))
    
        # adding to the dict that will be saved later using save() function above
        save_best_params[alg_name] = params
    
    run_total = time.perf_counter() - start_total
    print("Total optimization time was {:.2f} minutes".format(run_total/60))
    print('-'*30)

# %%
findBestParam(est_1,param_grid_1)
# Out:
# The best parameters for AdaBoostClassifier are {'algorithm': 'SAMME.R', 'learning_rate': 0.03, 'n_estimators': 300, 'random_state': 0} with runtime of 34.11 seconds
# The best parameters for BaggingClassifier are {'max_features': 0.5, 'n_estimators': 300, 'random_state': 0} with runtime of 38.44 seconds
# The best parameters for ExtraTreesClassifier are {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'n_estimators': 300, 'random_state': 0} with runtime of 2234.45 seconds
# The best parameters for GradientBoostingClassifier are {'learning_rate': 0.05, 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 0.03, 'n_estimators': 100, 'random_state': 0} with runtime of 3935.00 seconds
# The best parameters for RandomForestClassifier are {'criterion': 'entropy', 'max_depth': 4, 'n_estimators': 300, 'oob_score': True, 'random_state': 0} with runtime of 170.20 seconds
# Total optimization time was 106.87 minutes
# ------------------------------

# %% [markdown]
# # 2 |  Gaussian Processes

# %%
#http://scikit-learn.org/stable/modules/gaussian_process.html#gaussian-process-classification-gpc
est_2 = [
    ('gpc', gaussian_process.GaussianProcessClassifier())
]

# %%
# GaussianProcessClassifier
# https://scikit-learn.org/stable/modules/generated/sklearn.gaussian_process.GaussianProcessClassifier.html?highlight=gaussianprocessclassifier#sklearn.gaussian_process.GaussianProcessClassifier
param_grid_2 = [
            
            {
            'max_iter_predict': grid_n_estimator, #default=100
            'random_state': grid_seed
            }
            ]

# %%
findBestParam(est_2,param_grid_2)
# Out:
# The best parameters for GaussianProcessClassifier are {'max_iter_predict': 10, 'random_state': 0} with runtime of 3.11 seconds
# Total optimization time was 0.05 minutes
# ------------------------------

# %% [markdown]
# # 3 |  GLM  ❌
# According to the warnings and after tuing parameters , it seems that the model does not fit with my data.<br>
# [Source](https://stackoverflow.com/questions/31952991/what-does-the-verbosity-parameter-of-a-random-forest-mean-sklearn?rq=1#:~:text=Verbosity%20in%20keyword%20arguments%20usually,about%20the%20tree%20building%20process.)

# %%
#http://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
est_3 = [
    ('lr', linear_model.LogisticRegressionCV())
]

# %%
# LogisticRegressionCV
# http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegressionCV.html#sklearn.linear_model.LogisticRegressionCV
param_grid_3 = [
            {
            'fit_intercept': grid_bool, #default=100
            'solver': ['sag', 'saga'], #default: lbfgs
            'random_state' : grid_seed,
            'max_iter' : [100 , 300 , 500],
            'verbose' : [1 , 0]
            }
            ]

# %%
findBestParam(est_3,param_grid_3)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 19 epochs took 1 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 12 epochs took 0 seconds
# convergence after 23 epochs took 0 seconds
# convergence after 59 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 50 epochs took 0 seconds
# convergence after 13 epochs took 0 seconds
# convergence after 4 epochs took 0 seconds
# convergence after 3 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 17 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 12 epochs took 0 seconds
# convergence after 24 epochs took 0 seconds
# convergence after 59 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 54 epochs took 0 seconds
# convergence after 19 epochs took 0 seconds
# convergence after 4 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 18 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 12 epochs took 0 seconds
# convergence after 24 epochs took 0 seconds
# convergence after 60 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 62 epochs took 0 seconds
# convergence after 22 epochs took 0 seconds
# convergence after 7 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 18 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 10 epochs took 0 seconds
# convergence after 23 epochs took 0 seconds
# convergence after 59 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 48 epochs took 0 seconds
# convergence after 16 epochs took 0 seconds
# convergence after 5 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 16 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 10 epochs took 0 seconds
# convergence after 24 epochs took 0 seconds
# convergence after 61 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 59 epochs took 0 seconds
# convergence after 21 epochs took 0 seconds
# convergence after 4 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 19 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 12 epochs took 0 seconds
# convergence after 24 epochs took 0 seconds
# convergence after 61 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 51 epochs took 0 seconds
# convergence after 21 epochs took 0 seconds
# convergence after 4 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s finished
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 17 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 12 epochs took 0 seconds
# convergence after 24 epochs took 0 seconds
# convergence after 61 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 52 epochs took 0 seconds
# convergence after 19 epochs took 0 seconds
# convergence after 4 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 19 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 12 epochs took 0 seconds
# convergence after 25 epochs took 0 seconds
# convergence after 65 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 68 epochs took 0 seconds
# convergence after 28 epochs took 0 seconds
# convergence after 8 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 19 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 11 epochs took 0 seconds
# convergence after 24 epochs took 0 seconds
# convergence after 61 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 57 epochs took 0 seconds
# convergence after 18 epochs took 0 seconds
# convergence after 4 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 16 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 10 epochs took 0 seconds
# convergence after 24 epochs took 0 seconds
# convergence after 63 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 66 epochs took 0 seconds
# convergence after 25 epochs took 0 seconds
# convergence after 7 epochs took 0 seconds
# convergence after 3 epochs took 0 seconds
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s finished
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 16 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 10 epochs took 0 seconds
# convergence after 25 epochs took 0 seconds
# convergence after 60 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 40 epochs took 0 seconds
# convergence after 18 epochs took 0 seconds
# convergence after 4 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 16 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 10 epochs took 0 seconds
# convergence after 23 epochs took 0 seconds
# convergence after 57 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# convergence after 48 epochs took 0 seconds
# convergence after 15 epochs took 0 seconds
# convergence after 5 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 17 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 10 epochs took 0 seconds
# convergence after 23 epochs took 0 seconds
# convergence after 56 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 42 epochs took 0 seconds
# convergence after 15 epochs took 0 seconds
# convergence after 5 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 19 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 10 epochs took 0 seconds
# convergence after 22 epochs took 0 seconds
# convergence after 58 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s finished
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# convergence after 37 epochs took 0 seconds
# convergence after 17 epochs took 0 seconds
# convergence after 5 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 16 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 11 epochs took 0 seconds
# convergence after 24 epochs took 0 seconds
# convergence after 62 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 46 epochs took 0 seconds
# convergence after 17 epochs took 0 seconds
# convergence after 4 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 19 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 10 epochs took 0 seconds
# convergence after 24 epochs took 0 seconds
# convergence after 59 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 38 epochs took 0 seconds
# convergence after 17 epochs took 0 seconds
# convergence after 5 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 19 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 10 epochs took 0 seconds
# convergence after 23 epochs took 0 seconds
# convergence after 59 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 39 epochs took 0 seconds
# convergence after 15 epochs took 0 seconds
# convergence after 5 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 16 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 10 epochs took 0 seconds
# convergence after 24 epochs took 0 seconds
# convergence after 59 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# ...
# convergence after 10 epochs took 0 seconds
# convergence after 16 epochs took 0 seconds
# convergence after 38 epochs took 0 seconds
# convergence after 151 epochs took 0 seconds
# convergence after 363 epochs took 0 seconds
# convergence after 426 epochs took 0 seconds
# convergence after 248 epochs took 0 seconds
# convergence after 69 epochs took 0 seconds
# convergence after 10 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 13 epochs took 0 seconds
# convergence after 11 epochs took 0 seconds
# convergence after 16 epochs took 0 seconds
# convergence after 38 epochs took 0 seconds
# convergence after 152 epochs took 0 seconds
# convergence after 393 epochs took 0 seconds
# convergence after 480 epochs took 0 seconds
# convergence after 285 epochs took 0 seconds
# convergence after 79 epochs took 0 seconds
# convergence after 13 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 13 epochs took 0 seconds
# convergence after 11 epochs took 0 seconds
# convergence after 10 epochs took 0 seconds
# convergence after 38 epochs took 0 seconds
# convergence after 151 epochs took 0 seconds
# convergence after 366 epochs took 1 seconds
# convergence after 426 epochs took 0 seconds
# convergence after 247 epochs took 0 seconds
# convergence after 67 epochs took 0 seconds
# convergence after 10 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 9 epochs took 0 seconds
# convergence after 12 epochs took 0 seconds
# convergence after 16 epochs took 0 seconds
# convergence after 38 epochs took 0 seconds
# convergence after 150 epochs took 0 seconds
# convergence after 357 epochs took 0 seconds
# convergence after 414 epochs took 0 seconds
# convergence after 238 epochs took 0 seconds
# convergence after 66 epochs took 0 seconds
# convergence after 12 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 13 epochs took 0 seconds
# convergence after 11 epochs took 0 seconds
# convergence after 12 epochs took 0 seconds
# convergence after 38 epochs took 0 seconds
# convergence after 148 epochs took 0 seconds
# convergence after 387 epochs took 0 seconds
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# max_iter reached after 0 seconds
# convergence after 312 epochs took 0 seconds
# convergence after 89 epochs took 0 seconds
# convergence after 13 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 13 epochs took 0 seconds
# convergence after 11 epochs took 0 seconds
# convergence after 10 epochs took 0 seconds
# convergence after 38 epochs took 0 seconds
# convergence after 147 epochs took 0 seconds
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# convergence after 358 epochs took 0 seconds
# convergence after 439 epochs took 1 seconds
# convergence after 263 epochs took 0 seconds
# convergence after 71 epochs took 0 seconds
# convergence after 11 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 13 epochs took 0 seconds
# convergence after 11 epochs took 0 seconds
# convergence after 12 epochs took 0 seconds
# convergence after 37 epochs took 0 seconds
# convergence after 147 epochs took 0 seconds
# convergence after 360 epochs took 0 seconds
# convergence after 412 epochs took 0 seconds
# convergence after 237 epochs took 0 seconds
# convergence after 62 epochs took 0 seconds
# convergence after 11 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 13 epochs took 0 seconds
# convergence after 11 epochs took 0 seconds
# convergence after 10 epochs took 0 seconds
# convergence after 38 epochs took 0 seconds
# convergence after 147 epochs took 0 seconds
# convergence after 366 epochs took 0 seconds
# convergence after 446 epochs took 0 seconds
# convergence after 263 epochs took 0 seconds
# convergence after 72 epochs took 0 seconds
# convergence after 15 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 10 epochs took 0 seconds
# convergence after 11 epochs took 0 seconds
# convergence after 12 epochs took 0 seconds
# convergence after 38 epochs took 0 seconds
# convergence after 147 epochs took 0 seconds
# convergence after 344 epochs took 0 seconds
# convergence after 401 epochs took 0 seconds
# convergence after 231 epochs took 0 seconds
# convergence after 65 epochs took 0 seconds
# convergence after 7 epochs took 0 seconds
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.4s finished
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 15 epochs took 0 seconds
# convergence after 19 epochs took 0 seconds
# convergence after 56 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 62 epochs took 0 seconds
# convergence after 16 epochs took 0 seconds
# convergence after 3 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 15 epochs took 0 seconds
# convergence after 18 epochs took 0 seconds
# convergence after 57 epochs took 0 seconds
# max_iter reached after 1 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 50 epochs took 0 seconds
# convergence after 19 epochs took 0 seconds
# convergence after 4 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 15 epochs took 0 seconds
# convergence after 18 epochs took 0 seconds
# convergence after 55 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 42 epochs took 0 seconds
# convergence after 16 epochs took 0 seconds
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# convergence after 3 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 15 epochs took 0 seconds
# convergence after 18 epochs took 0 seconds
# convergence after 54 epochs took 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 36 epochs took 0 seconds
# convergence after 16 epochs took 0 seconds
# convergence after 3 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# rescaling...
# convergence after 15 epochs took 0 seconds
# convergence after 18 epochs took 0 seconds
# convergence after 56 epochs took 0 seconds
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# max_iter reached after 0 seconds
# convergence after 36 epochs took 0 seconds
# convergence after 13 epochs took 0 seconds
# convergence after 4 epochs took 0 seconds
# convergence after 2 epochs took 0 seconds
# The best parameters for LogisticRegressionCV are {'fit_intercept': True, 'max_iter': 100, 'random_state': 0, 'solver': 'saga', 'verbose': 1} with runtime of 134.58 seconds
# Total optimization time was 2.24 minutes
# ------------------------------
# /Users/yarasaleh/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.7s finished

# %% [markdown]
# # 4 |  Navies Bayes

# %%
#http://scikit-learn.org/stable/modules/naive_bayes.html
est_4 = [
    ('bnb', naive_bayes.BernoulliNB()),
    ('gnb', naive_bayes.GaussianNB())
]

# %%
# BernoulliNB
# http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.BernoulliNB.html#sklearn.naive_bayes.BernoulliNB

# GaussianNB
# https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html#sklearn.naive_bayes.GaussianNB

param_grid_4 = [
            {
            'alpha': grid_ratio #default=1.0
            },
            {}
            ]

# %%
findBestParam(est_4,param_grid_4)
# Out:
# The best parameters for BernoulliNB are {'alpha': 0.1} with runtime of 0.26 seconds
# The best parameters for GaussianNB are {} with runtime of 0.05 seconds
# Total optimization time was 0.01 minutes
# ------------------------------

# %% [markdown]
# # 5 |  Nearest Neighbor

# %%
#http://scikit-learn.org/stable/modules/neighbors.html
est_5 = [
    ('knc', neighbors.KNeighborsClassifier())
]

# %%
# KNeighborsClassifier
# http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html#sklearn.neighbors.KNeighborsClassifier

param_grid_5 = [
            {
            'n_neighbors': [1,2,3,4,5,6,7], #default = 5
            'weights' : ["uniform","distance"] ,
            'algorithm' : ['auto' , 'ball_tree' , 'kd_tree' , 'brute'] , # defualt = auto
            'leaf_size' : [10,20,30,40,50] # default = 30
            }
            ]

# %%
findBestParam(est_5,param_grid_5)
# Out:
# The best parameters for KNeighborsClassifier are {'algorithm': 'ball_tree', 'leaf_size': 40, 'n_neighbors': 7, 'weights': 'uniform'} with runtime of 22.36 seconds
# Total optimization time was 0.37 minutes
# ------------------------------

# %% [markdown]
# # 6 |  SVM

# %%
# SVC
#http://scikit-learn.org/stable/modules/svm.html
est_6 = [
    ('svc', svm.SVC(probability=True))
]

# %%
# SVC
# http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC

param_grid_6 = [
    {
    'C' : [1,2,3,4,5,6,7], # defualt = 1.0
    'gamma': ['scale' , 'auto'] ,
    'probability' : [True],
    'decision_function_shape' : ['ovo','ovr'],
    'random_state' : grid_seed
    }
]

# %%
findBestParam(est_6,param_grid_6)
# Out:
# The best parameters for SVC are {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 'scale', 'probability': True, 'random_state': 0} with runtime of 10.16 seconds
# Total optimization time was 0.17 minutes
# ------------------------------

# %% [markdown]
# # 7 |  Decision Tree

# %%
est_7 = [
    ('dtc', tree.DecisionTreeClassifier(max_depth = 4,
                                       min_samples_leaf = 5))
]

# %%
# Decision Tree
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier

param_grid_7 = [
    {
        'criterion' :  ['gini'],
        'splitter': ['best'],
        'max_depth': [2,4,6,None],
        'min_samples_split': [2,5,10],
        'min_samples_leaf': [1,5,10],
        'max_features': [None, 'auto','log2','sqrt'],
        'random_state': grid_seed
    }
]

# %%
findBestParam(est_7,param_grid_7)
# Out:
# The best parameters for DecisionTreeClassifier are {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 2, 'random_state': 0, 'splitter': 'best'} with runtime of 6.30 seconds
# Total optimization time was 0.11 minutes
# ------------------------------

# %% [markdown]
# # Save the results in a file

# %%
print(save_best_params) # 11 elements
# Out:
# {'AdaBoostClassifier': {'algorithm': 'SAMME.R', 'learning_rate': 0.03, 'n_estimators': 300, 'random_state': 0}, 'BaggingClassifier': {'max_features': 0.5, 'n_estimators': 300, 'random_state': 0}, 'ExtraTreesClassifier': {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'n_estimators': 300, 'random_state': 0}, 'GradientBoostingClassifier': {'learning_rate': 0.05, 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 0.03, 'n_estimators': 100, 'random_state': 0}, 'RandomForestClassifier': {'criterion': 'entropy', 'max_depth': 4, 'n_estimators': 300, 'oob_score': True, 'random_state': 0}, 'GaussianProcessClassifier': {'max_iter_predict': 10, 'random_state': 0}, 'BernoulliNB': {'alpha': 0.1}, 'GaussianNB': {}, 'KNeighborsClassifier': {'algorithm': 'ball_tree', 'leaf_size': 40, 'n_neighbors': 7, 'weights': 'uniform'}, 'SVC': {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 'scale', 'probability': True, 'random_state': 0}, 'DecisionTreeClassifier': {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 2, 'random_state': 0, 'splitter': 'best'}}

# %%
# https://stackabuse.com/reading-and-writing-json-to-a-file-in-python/
#results_file = "BestParams" 
def save(dictionary):
    with open('BestParams.txt', 'w') as outfile:
        json.dump(dictionary, outfile)

save(save_best_params)
